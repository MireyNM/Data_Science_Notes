# %% [markdown]
# ## What is CSS?
# ![Screen%20Shot%202023-09-02%20at%2010.44.14%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.44.14%20PM.png)

# %% [markdown]
# ## CSS on HTML elements
# ![Screen%20Shot%202023-09-02%20at%2010.45.17%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.45.17%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.45.47%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.45.47%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.46.29%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.46.29%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.47.17%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.47.17%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.47.52%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.47.52%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.55.25%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.55.25%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-02%20at%2010.55.55%20PM.png](attachment:Screen%20Shot%202023-09-02%20at%2010.55.55%20PM.png)

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

data = {
    'Major Category': ['Electronics', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Clothing'],
    'Minor Category': ['Laptops', 'Smartphones', 'Shirts', 'Dresses', 'Tablets', 'Jeans'],
    'Total Orders': [100, 150, 80, 60, 120, 75]
}

ecom_sales = pd.DataFrame(data)
ecom_category = ecom_sales.groupby(['Major Category','Minor Category']).size().reset_index(name='Total Orders').sort_values(by='Total Orders', ascending=False).reset_index(drop=True)
top_cat = ecom_category.loc[0]['Minor Category']
ecom_bar = px.bar(ecom_category, x='Total Orders', y='Minor Category', color='Major Category')
ecom_bar.update_layout({'yaxis':{'dtick':1, 'categoryorder':'total ascending'}, 'paper_bgcolor':'rgb(224, 255, 252)'})         

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1('Top Sales Categories'),
    # Set the size of the bar graph
    html.Div(dcc.Graph(figure=ecom_bar, 
                       style={'width':'1000px', 'height':'240px', 'margin':'auto'}),
    ),
    html.Br(),
    html.Span(children=[
    'The top category was: ',
    html.B(top_cat),
    html.Br(),
    html.I('Copyright E-Com INC',
    # Add a background color to the copyright notice
    style={'background-color':'lightgrey'})])
    # Add a background color to the entire app
    ], style={'text-align':'center', 'font-size':22, 'background-color':'rgb(224,255,252)'})


if __name__ == '__main__':
    app.run_server(port=8030, debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8030/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

logo_link = 'https://assets.datacamp.com/production/repositories/5893/datasets/1c95273e21a54b5ca48e0b03cc0c1faeafb3d7cd/e-comlogo_white.png'
ecom_category = ecom_sales.groupby(['Major Category','Minor Category']).size().reset_index(name='Total Orders').sort_values(by='Total Orders', ascending=False).reset_index(drop=True)
top_cat = ecom_category.loc[0]['Minor Category']
ecom_bar = px.bar(ecom_category, x='Total Orders', y='Minor Category', color='Major Category')

# Set the font color of the bar chart
ecom_bar.update_layout({'yaxis':{'dtick':1, 'categoryorder':'total ascending'}, 'paper_bgcolor':'black', 'font': {'color':'white'}})

app = dash.Dash(__name__)

app.layout = html.Div([
    # Set the new white-text image
    #html.Img(src='https://assets.datacamp.com/production/repositories/5893/datasets/1c95273e21a54b5ca48e0b03cc0c1faeafb3d7cd/e-comlogo_white.png',
    #style={'width':'165px', 'height':'50px'}),
    html.H1('Top Sales Categories'),
    html.Div(dcc.Graph(figure=ecom_bar,style={'width':'500px', 'height':'350px', 'margin':'auto'})),
    html.Br(),
    html.Span(children=[
    'The top category was: ',
    html.B(top_cat),
    html.Br(),
    html.I('Copyright E-Com INC')])
    ], style={'text-align':'center', 'font-size':22,
              # Update the background color to the entire app
              'background-color':'black',
              # Change the text color for the whole app
              'color':'white'
               })

if __name__ == '__main__':
    app.run_server(port=60301, debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:60301/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
