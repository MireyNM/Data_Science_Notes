# %% [markdown]
# # .sort( ) vs sorted( )
# I've noticed that every time I need to decide between using 'sort' or 'sorted' in Python, I find myself turning to Google and typing: "sort vs sorted in Python". </br>
#
# 👩🏻‍🏫 There's absolutely nothing wrong with Googling, but my experience as a teacher has shown me that learning tends to stick better when it's enjoyable and when we can come up with creative memory aids.</br>
#
# 🤔 Well, now I am the student and I guess it would be helpful to associate 'sort' with the present. Any changes made with 'sort' affect the list in-place, without leaving behind a past older version. On the other hand, 'sorted' creates a new sorted version, leaving the original one unaffected.  </br>
#
# ❓ Am I the only one who's got 'sorted' this out? Or are there more memory tricks out there you would like to share? Or maybe you're one of those beings who can remember everything? 🤓</br>

# %% [markdown]
# ![Screen%20Shot%202023-08-31%20at%204.36.15%20PM.png](attachment:Screen%20Shot%202023-08-31%20at%204.36.15%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-08-31%20at%204.36.25%20PM.png](attachment:Screen%20Shot%202023-08-31%20at%204.36.25%20PM.png)
