# %%
# Import datetime module
import datetime as dt

# %%
# Curent date
today_date = dt.date.today()
print(today_date)
# Out:
# 2023-06-01

# %%
date1 = dt.date(2023, 8,20)
print(date1)
# Out:
# 2023-08-20

# %% [markdown]
# ## The strptime() method creates a datetime object from the given string.
#
# ### datetime.strptime(date_string, format_string) <br/>
# format_string = "%a %d %b %Y %H:%M:%S %z" or "%d %B, %Y" ... <br/>
#
# %B: the month's name in full (August...)  <br/>
# %b: the month's number

# %%
from datetime import datetime

date_string = "21 June, 2018"

print("date_string =", date_string)
print("type of date_string =", type(date_string))

date_object = datetime.strptime(date_string, "%d %B, %Y")

print("date_object =", date_object)
print("type of date_object =", type(date_object))
# Out:
# date_string = 21 June, 2018
# type of date_string = <class 'str'>
# date_object = 2018-06-21 00:00:00
# type of date_object = <class 'datetime.datetime'>

# %% [markdown]
# ![Screen%20Shot%202023-06-01%20at%2012.04.02%20PM.png](attachment:Screen%20Shot%202023-06-01%20at%2012.04.02%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-06-01%20at%2012.04.14%20PM.png](attachment:Screen%20Shot%202023-06-01%20at%2012.04.14%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202023-06-01%20at%2012.04.23%20PM.png](attachment:Screen%20Shot%202023-06-01%20at%2012.04.23%20PM.png)
