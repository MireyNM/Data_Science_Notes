# %% [markdown]
# # 1- Using Window Functions (PostgreSQL, SQL Server, Oracle, etc.)
#
# You can use the PERCENTILE_CONT window function to calculate the median. This function takes a value between 0 and 1 (representing the desired percentile) and returns the corresponding value.
#
# Here's an example query to find the median of a column named value in a table named data:

# %% [markdown]
# ![Screen%20Shot%202023-08-23%20at%204.01.19%20PM.png](attachment:Screen%20Shot%202023-08-23%20at%204.01.19%20PM.png)

# %% [markdown]
# # 2 - Using Subqueries (Most Databases):
# You can use subqueries to find the median. This approach involves counting the number of rows, ordering them, and then selecting the middle value (or the average of two middle values).
#
# PS: Replace value and data with the appropriate column and table names in your database.

# %% [markdown]
# ![Screen%20Shot%202023-08-23%20at%204.02.18%20PM.png](attachment:Screen%20Shot%202023-08-23%20at%204.02.18%20PM.png)
