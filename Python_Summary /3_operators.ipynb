# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# ![Screen%20Shot%202024-07-21%20at%2012.20.06%20PM.png](attachment:Screen%20Shot%202024-07-21%20at%2012.20.06%20PM.png)

# %%
# You can't say 2 = 2 
# It's like assigning  2 for 
2 = 2
# Out:
#   File "/var/folders/22/6yjgvchj59n3fw3c208txjnm0000gn/T/ipykernel_63416/3767711206.py", line 3
#     2 = 2
#          ^
# SyntaxError: can't assign to literal

# %%
2 == 2
# Out:
# True

# %%
2 == 10
# Out:
# False

# %%
2!=10
# Out:
# True

# %%
"Chocolate" == "Milk"
# Out:
# False

# %%
2 < 8
# Out:
# True

# %%
8 < 8
# Out:
# False

# %%
8 <= 8
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# ![Screen%20Shot%202024-07-21%20at%2012.25.12%20PM.png](attachment:Screen%20Shot%202024-07-21%20at%2012.25.12%20PM.png)

# %%
(10>50) and (10> 2)
# Out:
# False

# %%
(2<5) and (2<30)
# Out:
# True

# %%
(10>50) or (10> 2)
# Out:
# True

# %%
# Takes alphabatical order
('Milk'>'Chocolate')
# Out:
# True

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# ![Screen%20Shot%202024-07-21%20at%2012.32.26%20PM.png](attachment:Screen%20Shot%202024-07-21%20at%2012.32.26%20PM.png)

# %%
my_list = [1, 2, 3, 4]
print(2 in my_list)  # True
print(5 in my_list)  # False
# Out:
# True
# False

# %%
my_string = "hello"
print("z" not in my_string)  # True
print("h" not in my_string)  # False
# Out:
# True
# False
