# %% [markdown]
# ![Screen%20Shot%202023-07-05%20at%2011.07.43%20AM.png](attachment:Screen%20Shot%202023-07-05%20at%2011.07.43%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'sockMerchant' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY ar
#

def sockMerchant(n, ar):
    # Write your code here
    # Create a dictionary to count the number of socks for each color
    color_dict = dict()
    
    # Count the number of socks for each color
    for i in range(len(ar)):
        if ar[i] in color_dict:
            color_dict[ar[i]] +=1
        else:
            color_dict[ar[i]] = 1
    
    # Find the total number of pairs 
    nb_pairs = 0
    for value in color_dict.values():
        nb_pairs += int(value/2)
    
    # In HR 
    # return nb_pairs
    print (nb_pairs)
            

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    ar = list(map(int, input().rstrip().split()))

    result = sockMerchant(n, ar)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 9
# 10 20 20 10 10 30 50 10 20
# 3
