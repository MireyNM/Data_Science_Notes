# %% [markdown]
# ![Screen%20Shot%202023-07-03%20at%2011.14.59%20AM.png](attachment:Screen%20Shot%202023-07-03%20at%2011.14.59%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthday' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER_ARRAY s
#  2. INTEGER d
#  3. INTEGER m
#

def birthday(s, d, m):
    # Write your code here
    count = 0
    substrings = []

    # Find all possible substrings
    if m < len(s):
        for i in range(0,len(s) - 1):
            substring = s[i:i+m]
            substrings.append(substring)
                       
    elif m ==len(s):
        substring = s
        substrings.append(substring)
        
    # Find if the sum of each substring is equal d     
    for substring in substrings:
        if sum(substring) == d:
                count += 1
   
    # in HR write
    # return count
    print(count)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    s = list(map(int, input().rstrip().split()))

    first_multiple_input = input().rstrip().split()

    d = int(first_multiple_input[0])

    m = int(first_multiple_input[1])

    result = birthday(s, d, m)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 5
# 2 2 1 3 2
# 4 2
# 2

# %% [markdown]
# ### Explanation

# %%
n = 5
s = [2,2,1,3,2]
d =4
m = 2 
count = 0
substrings = []

for i in range(len(s) - 1):
    # Find all possible substrings
    substring = s[i:i+m]
    substrings.append(substring)
    
    # Find if the sum of each substring is equal d 
    if sum(substring) == d:
        count += 1
        
print(substrings)
print(count)
# Out:
# [[2, 2], [2, 1], [1, 3], [3, 2]]
# 2

# %% [markdown]
# What if m > len(s) or m = len(s)??
#
# We should update the code to take into consideration these cases

# %%
n = 1
s = [4]
d =4
m = 1 
count = 0
substrings = []


# Find all possible substrings
if m < len(s):
    for i in range(0,len(s) - 1):
        substring = s[i:i+m]
        substrings.append(substring)
                       
elif m ==len(s):
    substring = s
    substrings.append(substring)
        
# Find if the sum of each substring is equal d     
for substring in substrings:
    if sum(substring) == d:
             count += 1
print(count)
# Out:
# 1
