# %% [markdown]
# ![Screen%20Shot%202023-08-09%20at%2010.21.46%20AM.png](attachment:Screen%20Shot%202023-08-09%20at%2010.21.46%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-08-09%20at%2010.22.08%20AM.png](attachment:Screen%20Shot%202023-08-09%20at%2010.22.08%20AM.png)

# %%
### !/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'missingNumbers' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY arr
#  2. INTEGER_ARRAY brr
#
def missingNumbers(arr, brr):
    # Write your code here
    
    # Use Counter to count occurrences of each element in the array
    element_counts_arr = Counter(arr)
    
    element_counts_brr = Counter(brr)
    
    missing = []
    
    # Add missing numbers from brr
    missing = [nb for nb in arr if nb not in brr]
    
    # Add missing numbers from arr
    missing = [nb2 for nb2 in brr if nb2 not in arr]

    # Add nb which exist in both arrays but with different occurrence 
    for elea, counta in element_counts_arr.items():
        for eleb, countb in element_counts_brr.items():
            if elea == eleb and counta != countb:
                missing.append(elea)
      
    
    return (sorted(missing))

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    m = int(input().strip())

    brr = list(map(int, input().rstrip().split()))

    result = missingNumbers(arr, brr)
    
    print(result)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 10
# 203 204 205 206 207 208 203 204 205 206
# 13
# 203 204 204 205 206 207 205 208 203 206 205 206 204
# [204, 205, 206]

# %% [markdown]
# # Optimized Version

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
from collections import Counter

#
# Complete the 'missingNumbers' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY arr
#  2. INTEGER_ARRAY brr
#


def missingNumbers(arr, brr):
    arr_counter = Counter(arr)
    brr_counter = Counter(brr)

    missing = []

    # Compare the counters to find missing and different occurrences
    for num, count_b in brr_counter.items():
        count_a = arr_counter.get(num, 0)
        if count_a < count_b:
            missing.extend([num] * (count_b - count_a))

    return sorted(missing)

      
    
    return (sorted(missing))

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    m = int(input().strip())

    brr = list(map(int, input().rstrip().split()))

    result = missingNumbers(arr, brr)
    
    print(result)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 10
# 203 204 205 206 207 208 203 204 205 206
# 13
# 203 204 204 205 206 207 205 208 203 206 205 206 204
# [204, 205, 206]
