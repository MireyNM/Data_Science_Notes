# %% [markdown]
# ![Screen%20Shot%202023-08-16%20at%209.27.11%20AM.png](attachment:Screen%20Shot%202023-08-16%20at%209.27.11%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-08-16%20at%209.27.25%20AM.png](attachment:Screen%20Shot%202023-08-16%20at%209.27.25%20AM.png)

# %% [markdown]
# # Code with time limit error

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'sansaXor' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def sansaXor(arr):
    xor_result = 0

    for start in range(n):
        xor_sum = 0
        for end in range(start, n):
            xor_sum ^= arr[end]
            xor_result ^= xor_sum

    return xor_result

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input().strip())

    for t_itr in range(t):
        n = int(input().strip())

        arr = list(map(int, input().rstrip().split()))

        result = sansaXor(arr)
        print(result)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# 3
# 1 2 3
# 2

# %% [markdown]
# ## Optimised code

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
from itertools import permutations
#
# Complete the 'sansaXor' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def sansaXor(arr):
    # Write your code here
    
    result = 0
    
    for i in range(n):
        freq = (i + 1) * (n - i)
        if freq % 2 == 1:
            result ^= arr[i]
    
    return result

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input().strip())

    for t_itr in range(t):
        n = int(input().strip())

        arr = list(map(int, input().rstrip().split()))

        result = sansaXor(arr)
        print(result)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 2
# 3
# 1 2 3
# 2
# 4
# 4 5 7 5
# 0
