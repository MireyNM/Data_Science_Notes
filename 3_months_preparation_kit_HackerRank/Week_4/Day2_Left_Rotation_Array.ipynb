# %% [markdown]
# ![Screen%20Shot%202023-07-18%20at%209.25.30%20AM.png](attachment:Screen%20Shot%202023-07-18%20at%209.25.30%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-07-18%20at%209.25.54%20AM.png](attachment:Screen%20Shot%202023-07-18%20at%209.25.54%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'rotateLeft' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER d
#  2. INTEGER_ARRAY arr
#

def rotateLeft(d, arr):
    # Write your code here
    for _ in range(d):
        var = arr[0]
        for i in range(0,n-1):
            arr[i] =arr[i+1]
        arr[n-1] = var
    #return arr
    print (arr)       

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0]) # 5

    d = int(first_multiple_input[1])  # 4

    arr = list(map(int, input().rstrip().split())) # 1 2 3 4 5

    result = rotateLeft(d, arr)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 5 4
# 1 2 3 4 5
# [5, 1, 2, 3, 4]

# %% [markdown]
# ### Time limit exceeded
# To optimize the code for the rotateLeft function, you can use a more efficient approach to perform the rotation. Rather than shifting the elements one by one in a loop, you can utilize array slicing to achieve the rotation in a single step. Here's an optimized version of the code:

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'rotateLeft' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER d
#  2. INTEGER_ARRAY arr
#

def rotateLeft(d, arr):
    # Write your code here
    rotated = arr[d:] + arr[:d]
    #return rotated
    print(rotated)       

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0])

    d = int(first_multiple_input[1])

    arr = list(map(int, input().rstrip().split()))

    result = rotateLeft(d, arr)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 5 4
# 1 2 3 4 5
# [5, 1, 2, 3, 4]

# %% [markdown]
# The rotation is performed using array slicing.
#
# The arr[d:] part selects the elements starting from index d to the end of the array, and arr[:d] selects the elements from the beginning of the array up to index d.
#
# By concatenating these slices, you obtain the rotated array.
