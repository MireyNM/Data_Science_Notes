# %% [markdown]
# ![Screen%20Shot%202023-07-21%20at%2010.28.23%20AM.png](attachment:Screen%20Shot%202023-07-21%20at%2010.28.23%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'separateNumbers' function below.
#
# The function accepts STRING s as parameter.
#

def separateNumbers(s):
    # Write your code here
    # Write your code here
    found = False
    
    for i in range(len(s)//2):
        # Extract a substring and convert it to an integer
        f = int(s[:i+1])
        
        # Generate the pattern using increasing numbers starting from f
        a = str(f)
        while len(a) < len(s):
            f += 1
            a += str(f)
        
        # Check if the generated pattern matches the input string
        if a == s:
            found = True
            print('YES', int(s[:i+1]))
            break
    
    if not found:
        print('NO')
   

if __name__ == '__main__':
    q = int(input().strip())

    for q_itr in range(q):
        s = input()

        separateNumbers(s)
# Out:
# 1
# 91011
# YES 9
