# %% [markdown]
# ![Screen%20Shot%202023-07-17%20at%209.36.35%20AM.png](attachment:Screen%20Shot%202023-07-17%20at%209.36.35%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'pickingNumbers' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY a as parameter.
#

def pickingNumbers(a):
    # Write your code here
    max_length = 0

    for num in a:
        count = a.count(num)
        count_plus_one = a.count(num + 1)
        length = count + count_plus_one
        max_length = max(max_length, length)

    #return max_length
    print(max_length)           

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    a = list(map(int, input().rstrip().split())) # 1 1 2 2 4 4 5 5 5 
    

    result = pickingNumbers(a)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 9
# 1 1 2 2 4 4 5 5 5
# 5
