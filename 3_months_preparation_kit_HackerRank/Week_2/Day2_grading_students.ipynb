# %% [markdown]
# ![Screen%20Shot%202023-06-15%20at%209.48.47%20AM.png](attachment:Screen%20Shot%202023-06-15%20at%209.48.47%20AM.png)

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'gradingStudents' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY grades as parameter.
#

def gradingStudents(grades):
    # Write your code here
    multiple_5 = []
    for x in range(0,101):
        if x%5 ==0:
            multiple_5.append(x)
    multiple_5.reverse()
    
    nearest_multiple = 0
    
    for grade in grades: 
    
        if grade > 40:
        
            for nb in multiple_5:
                if grade < nb:
                    nearest_multiple = nb
                    #print(nearest_multiple)
                    continue
               
                else: 
                    break
            if nearest_multiple-grade <3:   
                index = grades.index(grade)
                grades[index] = nearest_multiple    
    
        print(grade)
        

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    grades_count = int(input().strip())

    grades = []

    for _ in range(grades_count):
        grades_item = int(input().strip())
        grades.append(grades_item)

    result = gradingStudents(grades)

    #fptr.write('\n'.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 3
# 20
# 92
# 81
# 20
# 92
# 81

# %% [markdown]
# # Explaination
# ## Created a list of multiple 5 numbers less than 100

# %%
multiple_5 = []
for x in range(0,101):
    if x%5 ==0:
        multiple_5.append(x)
multiple_5.reverse()
print(multiple_5)
# Out:
# [100, 95, 90, 85, 80, 75, 70, 65, 60, 55, 50, 45, 40, 35, 30, 25, 20, 15, 10, 5, 0]

# %% [markdown]
# ## Found the nearest multiple to the grade and then did the iterations

# %%
nearest_multiple = 0
grades = [20, 82, 91]
for grade in grades: 
    
    if grade > 40:
        
        for nb in multiple_5:
            if grade < nb:
                nearest_multiple = nb
            
                continue
               
            else: 
                break
        print(nearest_multiple)       
        
        if nearest_multiple-grade <3: 
            index = grades.index(grade)
            grades[index] = nearest_multiple    
            #print(grade)
        
print(grades)
# Out:
# 85
# 95
# [20, 82, 91]
