# %% [markdown]
# ![Screen%20Shot%202023-06-14%20at%2011.13.38%20AM.png](attachment:Screen%20Shot%202023-06-14%20at%2011.13.38%20AM.png)

# %% [markdown]
# ## Using dictionary

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'lonelyinteger' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY a as parameter.
#

def lonelyinteger(a):
    # Write your code here
    counting=dict()
    for i in range(0,len(a)):
        if a[i] not in counting:
            counting[a[i]]=1
        else:
            counting[a[i]]+=1
    
    for key, value in counting.items():
        if value ==1:
            print(key)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    a = list(map(int, input().rstrip().split()))

    result = lonelyinteger(a)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 5
# 1 2 2 3 3
# 1

# %% [markdown]
# ## Using .count()

# %%
def lonelyinteger(a):
    # Write your code here
    for nb in a:
        if a.count(nb)==1:
            print(nb)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    a = list(map(int, input().rstrip().split()))

    result = lonelyinteger(a)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 5
# 1 2 2 3 3
# 1

# %% [markdown]
# ## 1 line solution

# %%
return [x for x in a if a.count(x) == 1][0]
