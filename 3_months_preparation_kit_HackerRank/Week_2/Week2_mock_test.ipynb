# %% [markdown]
# ![Screen%20Shot%202023-06-28%20at%2010.51.47%20AM.png](attachment:Screen%20Shot%202023-06-28%20at%2010.51.47%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'flippingMatrix' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY matrix as parameter.
#

def flippingMatrix(matrix):
    # Write your code here
    len(matrix)
    s=0

    for i in range(n//2):
        for j in range(n//2):
            s += max(matrix[i][j], matrix[i][n-j-1],matrix[n-i-1][j],matrix[n-i-1][n-j-1])
        print(s)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')
    print(matrix)
    # Nb of queries 
    q = int(input().strip())

    for q_itr in range(q):
        n = int(input().strip())

        matrix = []

        for _ in range(2 * n):
            matrix.append(list(map(int, input().rstrip().split())))

        result = flippingMatrix(matrix)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# [[112, 42, 83, 119], [56, 125, 56, 49], [15, 78, 101, 43], [62, 98, 114, 108]]
# 1
# 2
# 112 42 83 119
# 56 125 56 49
# 56 125 56 49
# 56 125 56 49
# 125

# %% [markdown]
# # Tip
# We need to compare the numbers that can be switched together.  </br>
# Example: matrix[0][0] can be switched with: </br>
#         - matrix[0][3]  </br>
#         - matrix[3][0]   </br>
#         - matrix[3][3]   </br>
