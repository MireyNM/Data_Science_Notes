# %% [markdown]
# ![Screen%20Shot%202023-06-19%20at%2010.56.44%20AM.png](attachment:Screen%20Shot%202023-06-19%20at%2010.56.44%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'diagonalDifference' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.
#

def diagonalDifference(arr):
    # Write your code here
    
    # Find the sum of primary diagonal 
    sum_primary = 0
    for nb in range(n):
        sum_primary += arr[nb-1][nb-1]
  

    # Find the sum of secondary diagonal 
    sum_sec = 0
    for nb in range(n):
        sum_sec += arr[nb][n-(1+nb)]
    print((abs(sum_primary - sum_sec)))
    # In Hacker Ranck write return instead od print
    # return (abs(sum_primary - sum_sec))
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    result = diagonalDifference(arr)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 3
# 11 2 4
# 4 5 6
# 10 8 -12
# 15
