# %% [markdown]
# ![Screen%20Shot%202023-06-22%20at%2010.02.13%20AM.png](attachment:Screen%20Shot%202023-06-22%20at%2010.02.13%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'countingValleys' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER steps
#  2. STRING path
#

def countingValleys(steps, path):
    # Write your code here
    sea_level = 0
    count_valleys = 0
    
    for letter in path:
        if letter == 'U':
            sea_level +=1 
        elif letter == 'D':
            sea_level -=1 
        
        if sea_level == 0 and letter =='U':
            count_valleys +=1 
        
    # In HR instead of print write 
    # return(count_valleys)
    print(count_valleys) 
              
            

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    steps = int(input().strip())

    path = input()

    result = countingValleys(steps, path)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 12
# DDUUDDUDUUUD
# 2
