# %% [markdown]
# ![Screen%20Shot%202023-06-07%20at%2012.12.16%20PM.png](attachment:Screen%20Shot%202023-06-07%20at%2012.12.16%20PM.png)

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'breakingRecords' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY scores as parameter.
#

def breakingRecords(scores):
    # Write your code here
    first_score = scores[0]
    min_score = first_score
    max_score = first_score
    count_min = 0
    count_max = 0
    
    for i in range(1,len(scores)):
        if scores[i] < min_score:
            count_min +=1
            min_score = scores[i]
        elif scores[i] > max_score:
            count_max +=1 
            max_score = scores[i]

    return [count_max, count_min]



#n = int(input().strip())

scores = list(map(int, input().rstrip().split(','))) # 12,24,10,24

breakingRecords(scores)
# Out:
# 12,24,10,24
# [1, 1]
