# %% [markdown]
# ![Screen%20Shot%202023-08-24%20at%2011.53.09%20AM.png](attachment:Screen%20Shot%202023-08-24%20at%2011.53.09%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-08-24%20at%2011.53.37%20AM.png](attachment:Screen%20Shot%202023-08-24%20at%2011.53.37%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'gamingArray' function below.
#
# The function is expected to return a STRING.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def gamingArray(arr):
    # Write your code here
    max_ele = -1 
    max_count = 0 
    
    for ele in arr: 
        if ele > max_ele: 
            max_ele = ele
            max_count += 1 

    if max_count %2 != 0:
        return "BOB" 
    return "ANDY"

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    g = int(input().strip())

    for g_itr in range(g):
        arr_count = int(input().strip())

        arr = list(map(int, input().rstrip().split()))

        result = gamingArray(arr)
        
        print(result)

        #fptr.write(result + '\n')

    #fptr.close()
# Out:
# 2
# 5
# 5 2 6 3 4
# ANDY
# 2
# 3 1
# BOB
