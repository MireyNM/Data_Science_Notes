# %% [markdown]
# ![Screen%20Shot%202023-09-05%20at%2011.02.45%20AM.png](attachment:Screen%20Shot%202023-09-05%20at%2011.02.45%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-09-05%20at%2011.03.02%20AM.png](attachment:Screen%20Shot%202023-09-05%20at%2011.03.02%20AM.png)

# %% [markdown]
# ## Code with Time Limit Error

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'sumXor' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts LONG_INTEGER n as parameter.
#

def sumXor(n):
    # Write your code here
    count = 0
    for i in range(0,n+1):
        if n+i == n^i:
            count +=1
            
    return count

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = sumXor(n)
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 5
# 2

# %% [markdown]
# ## Optimized code

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'sumXor' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts LONG_INTEGER n as a parameter.
#

def sumXor(n):
    # Count the number of unset bits (0s) in the binary representation of n.
    count = 0
    while n > 0:
        if n % 2 == 0:
            count += 1
        n //= 2
    return 2 ** count  # Calculate 2^count to get the final result

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = sumXor(n)
    
    print(result)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 5
# 2
