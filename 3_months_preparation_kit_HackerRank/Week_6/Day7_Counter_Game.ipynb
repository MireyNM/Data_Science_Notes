# %% [markdown]
# ![Screen%20Shot%202023-08-31%20at%2011.28.37%20AM.png](attachment:Screen%20Shot%202023-08-31%20at%2011.28.37%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-08-31%20at%2011.29.00%20AM.png](attachment:Screen%20Shot%202023-08-31%20at%2011.29.00%20AM.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
import math

#
# Complete the 'counterGame' function below.
#
# The function is expected to return a STRING.
# The function accepts LONG_INTEGER n as parameter.
#

def counterGame(n):
    # Write your code here
    Louise = False
    list_power_2 = []
    
    # Create a list of number of power 2 less than n
    for i in range(1,n):
        if i**2 < n:
            list_power_2.append(i**2)
    #print(list_power_2)
        
    while n !=1:
        if math.sqrt(n)% 2 ==0:
            n = n/2 
            #print(n)
        else: 
            list_power_2 = [ele for ele in list_power_2 if ele < n]
            n = n - list_power_2[-1]
            #print(n)
        Louise = not Louise 
    
    if Louise == True:
        return 'Louise'
    return 'Richard'

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input().strip())

    for t_itr in range(t):
        n = int(input().strip())

        result = counterGame(n)
        
        print(result)

        #fptr.write(result + '\n')

    #fptr.close()
# Out:
# 1
# 132
# Louise

# %% [markdown]
# # Optimized code to solve Time Error
